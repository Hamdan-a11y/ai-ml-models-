# %% [markdown]
# # Decision Tree Assignment

# %%
import kagglehub
path = kagglehub.dataset_download("sarveshchhetri/play-tennis-practice-dataset-for-classification")
# Out:
# Using Colab cache for faster access to the 'play-tennis-practice-dataset-for-classification' dataset.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib
import matplotlib.pyplot as plt

import kagglehub
path = kagglehub.dataset_download("sarveshchhetri/play-tennis-practice-dataset-for-classification")
d=pd.read_csv("/kaggle/input/play-tennis-practice-dataset-for-classification/playtennis.csv")

le = LabelEncoder()
for col in d.columns:
  if d[col].dtype == "object":
    d[col] = le.fit_transform(d[col])
d

x=d.drop('PlayTennis',axis=1)
y=d['PlayTennis']


x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)


model = DecisionTreeClassifier(max_depth = 9)


model.fit(x_train,y_train)
train = model.score(x_train,y_train)
train
svm_y=model.predict(x_test)
print("R2 Score:", r2_score(y_test, svm_y))

import joblib
joblib.dump(model,"model.pkl")
# Out:
# Using Colab cache for faster access to the 'play-tennis-practice-dataset-for-classification' dataset.
# R2 Score: 0.8958333333333334
# ['model.pkl']
