# %%
import kagglehub
path = kagglehub.dataset_download("jayaantanaath/student-habits-vs-academic-performance")
# Out:
# Using Colab cache for faster access to the 'student-habits-vs-academic-performance' dataset.

# %%
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
csv_path = next(Path(path).rglob("student_habits_performance.csv"))
d = pd.read_csv(csv_path)
LE = LabelEncoder()
d['gender'] = LE.fit_transform(d['gender'])
d['part_time_job'] = LE.fit_transform(d['part_time_job'])
d['diet_quality'] = LE.fit_transform(d['diet_quality'])
d['parental_education_level'] = LE.fit_transform(d['parental_education_level'])
d['internet_quality'] = LE.fit_transform(d['internet_quality'])
d['extracurricular_participation'] = LE.fit_transform(d['extracurricular_participation'])
d=d.drop('student_id', axis=1)
x=d.drop('mental_health_rating', axis=1)

y=d['mental_health_rating']

s=StandardScaler()
x=s.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

model=RandomForestRegressor(n_estimators=300, random_state=42)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print(r2_score(y_test,y_pred))
d
# Out:
# -0.41807246955480126
#      age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0     23       0                  0.0                 1.2            1.1
# 1     20       0                  6.9                 2.8            2.3
# 2     21       1                  1.4                 3.1            1.3
# 3     23       0                  1.0                 3.9            1.0
# 4     19       0                  5.0                 4.4            0.5
# ..   ...     ...                  ...                 ...            ...
# 995   21       0                  2.6                 0.5            1.6
# 996   17       0                  2.9                 1.0            2.4
# 997   20       1                  3.0                 2.6            1.3
# 998   24       1                  5.4                 4.1            1.1
# 999   19       0                  4.3                 2.9            1.9
#
#      part_time_job  attendance_percentage  sleep_hours  diet_quality  \
# 0                0                   85.0          8.0             0
# 1                0                   97.3          4.6             1
# 2                0                   94.8          8.0             2
# 3                0                   71.0          9.2             2
# 4                0                   90.9          4.9             0
# ..             ...                    ...          ...           ...
# 995              0                   77.0          7.5             0
# 996              1                   86.0          6.8             2
# 997              0                   61.9          6.5             1
# 998              1                  100.0          7.6             0
# 999              0                   89.4          7.1             1
#
#      exercise_frequency  parental_education_level  internet_quality  \
# 0                     6                         2                 0
# 1                     6                         1                 0
# 2                     1                         1                 2
# 3                     4                         2                 1
# 4                     3                         2                 1
# ..                  ...                       ...               ...
# 995                   2                         1                 1
# 996                   1                         1                 0
# 997                   5                         0                 1
# 998                   0                         0                 0
# 999                   2                         0                 0
#
#      mental_health_rating  extracurricular_participation  exam_score
# 0                       8                              1        56.2
# 1                       8                              0       100.0
# 2                       1                              0        34.3
# 3                       1                              1        26.8
# 4                       1                              0        66.4
# ..                    ...                            ...         ...
# 995                     6                              1        76.1
# 996                     6                              1        65.9
# 997                     9                              1        64.4
# 998                     1                              0        69.7
# 999                     8                              0        74.9
#
# [1000 rows x 15 columns]

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from pathlib import Path
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
csv_path = next(Path(path).rglob("student_habits_performance.csv"))
d = pd.read_csv(csv_path)
LE = LabelEncoder()
d['gender'] = LE.fit_transform(d['gender'])
d['part_time_job'] = LE.fit_transform(d['part_time_job'])
d['diet_quality'] = LE.fit_transform(d['diet_quality'])
d['parental_education_level'] = LE.fit_transform(d['parental_education_level'])
d['internet_quality'] = LE.fit_transform(d['internet_quality'])
d['extracurricular_participation'] = LE.fit_transform(d['extracurricular_participation'])
d=d.drop('student_id', axis=1)
x=d.drop('exam_score', axis=1)

y=d['exam_score']

s=StandardScaler()
x=s.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

model=RandomForestRegressor(n_estimators=300)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 from sklearn.preprocessing import StandardScaler, LabelEncoder
#       4 from sklearn.model_selection import train_test_split
#       5 import joblib
#       6 from  sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# ----> 7 import seaborn as sns
#       8 import matplotlib.pyplot as plt
#       9 d = pd.read_csv("/kaggle/input/student-habits-vs-academic-performance/student_habits_performance.csv")
#      10 LE = LabelEncoder()
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from pathlib import Path
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

csv_path = next(Path(path).rglob("student_habits_performance.csv"))
d = pd.read_csv(csv_path)
LE = LabelEncoder()
d['gender'] = LE.fit_transform(d['gender'])
d['part_time_job'] = LE.fit_transform(d['part_time_job'])
d['diet_quality'] = LE.fit_transform(d['diet_quality'])
d['parental_education_level'] = LE.fit_transform(d['parental_education_level'])
d['internet_quality'] = LE.fit_transform(d['internet_quality'])
d['extracurricular_participation'] = LE.fit_transform(d['extracurricular_participation'])
d=d.drop('student_id', axis=1)
x=d.drop('exercise_frequency', axis=1)

y=d['exercise_frequency']

s=StandardScaler()
x=s.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

model=RandomForestRegressor(n_estimators=300)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print(r2_score(y_test,y_pred))
